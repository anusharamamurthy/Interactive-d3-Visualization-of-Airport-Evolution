# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('1987.csv', delimiter=',',engine='python')
df[:5]
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10          14          3      741         730      912
# 1  1987     10          15          4      729         730      903
# 2  1987     10          17          6      741         730      918
# 3  1987     10          18          7      729         730      847
# 4  1987     10          19          1      749         730      922
#
#    CRSArrTime UniqueCarrier  FlightNum        ...          TaxiIn  TaxiOut  \
# 0         849            PS       1451        ...             NaN      NaN
# 1         849            PS       1451        ...             NaN      NaN
# 2         849            PS       1451        ...             NaN      NaN
# 3         849            PS       1451        ...             NaN      NaN
# 4         849            PS       1451        ...             NaN      NaN
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
new_df = df[['Year','Dest','Origin']]

# %%
pd.unique(new_df.values.ravel())
# Out:
# array([1987, 'SFO', 'SAN', 'RNO', 'OAK', 'BUR', 'LAX', 'PHX', 'PDX', 'SJC',
#        'LAS', 'SNA', 'SMF', 'ABQ', 'GEG', 'SCK', 'MFR', 'MRY', 'TUS',
#        'EUG', 'SEA', 'RDM', 'FAT', 'LGB', 'ONT', 'CCR', 'BLI', 'YKM',
#        'PSC', 'STL', 'JFK', 'HNL', 'MIA', 'SJU', 'DEN', 'DAY', 'CVG',
#        'DCA', 'ORF', 'DTW', 'TUL', 'SYR', 'LGA', 'BOS', 'PHL', 'TPA',
#        'ORD', 'MCO', 'CLE', 'COS', 'MKE', 'IAD', 'CMH', 'EWR', 'PIT',
#        'IND', 'HOU', 'SAT', 'MCI', 'OKC', 'FLL', 'BNA', 'DFW', 'BWI',
#        'BDL', 'LIT', 'ICT', 'SLC', 'SDF', 'IAH', 'JAX', 'PSP', 'ANC',
#        'MSY', 'OMA', 'SRQ', 'RSW', 'PBI', 'ATL', 'MDW', 'AUS', 'MSP',
#        'MDT', 'MLI', 'MSN', 'CLT', 'FSD', 'DSM', 'RDU', 'LEX', 'PIA',
#        'MEM', 'SGF', 'CMI', 'CID', 'SUX', 'LNK', 'TOL', 'RST', 'ALO',
#        'OGG', 'FAI', 'KOA', 'ROC', 'MBS', 'LIH', 'SBA', 'BUF', 'ALB',
#        'ISP', 'PVD', 'GSO', 'GRR', 'BIL', 'HSV', 'BHM', 'SAV', 'CAE',
# ...

# %%
#new_df.drop_duplicates('Dest', inplace = True)

# %%
new_df
# Out:
#          Year Dest Origin
# 0        1987  SFO    SAN
# 1        1987  SFO    SAN
# 2        1987  SFO    SAN
# 3        1987  SFO    SAN
# 4        1987  SFO    SAN
# 5        1987  SFO    SAN
# 6        1987  SFO    SAN
# 7        1987  SFO    SAN
# 8        1987  SFO    SAN
# 9        1987  SFO    SAN
# 10       1987  SFO    SAN
# 11       1987  SFO    SAN
# 12       1987  SFO    SAN
# 13       1987  SFO    SAN
# 14       1987  RNO    SFO
# 15       1987  RNO    SFO
# 16       1987  RNO    SFO
# 17       1987  RNO    SFO
# 18       1987  RNO    SFO
# 19       1987  RNO    SFO
# 20       1987  RNO    SFO
# 21       1987  RNO    SFO
# 22       1987  RNO    SFO
# 23       1987  RNO    SFO
# 24       1987  RNO    SFO
# 25       1987  RNO    SFO
# 26       1987  RNO    SFO
# 27       1987  RNO    SFO
# 28       1987  RNO    SFO
# 29       1987  RNO    SFO
# ...       ...  ...    ...
# 1311796  1987  ORD    EWR
# 1311797  1987  ORD    EWR
# 1311798  1987  ORD    EWR
# ...

# %%
df97 = pd.read_csv('1997.csv', delimiter=',',engine='python')
new_df97 = df97[['Year','Dest','Origin']]
new_df97.drop_duplicates('Dest', inplace = True)
new_df97
# Out:
# /Users/aramamurthy/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/util/decorators.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return func(*args, **kwargs)
#          Year Dest Origin
# 0        1997  PHX    ABQ
# 13585    1997  PIT    ABE
# 23873    1997  PNS    ATL
# 24365    1997  PSC    GEG
# 24489    1997  PSG    JNU
# 24551    1997  PSP    DEN
# 24915    1997  PVD    ATL
# 26617    1997  PWM    ALB
# 27170    1997  RAP    MSP
# 27237    1997  RDU    ATL
# 29543    1997  RIC    ATL
# 30893    1997  RNO    BOI
# 33190    1997  ROA    CLT
# 33438    1997  ROC    ATL
# 34785    1997  RST    MSP
# 35078    1997  RSW    ATL
# 36663    1997  SAN    ABQ
# 42415    1997  SAT    ATL
# 45711    1997  SAV    AGS
# 46176    1997  SBA    SFO
# 46293    1997  SBN    CVG
# ...

# %%
df08 = pd.read_csv('2008.csv', delimiter=',',engine='python')

# %%
new_df08 = df08[['Year','Dest','Origin']]
new_df08.drop_duplicates('Dest', inplace = True)
new_df08
# Out:
#          Year Dest Origin
# 0        2008  TPA    IAD
# 2        2008  BWI    IND
# 5        2008  JAX    IND
# 6        2008  LAS    IND
# 8        2008  MCI    IND
# 10       2008  MCO    IND
# 12       2008  MDW    IND
# 16       2008  PHX    IND
# 26       2008  FLL    ISP
# 40       2008  PBI    ISP
# 43       2008  RSW    ISP
# 49       2008  HOU    JAN
# 56       2008  BHM    JAX
# 57       2008  BNA    JAX
# 71       2008  IND    JAX
# 72       2008  ORF    JAX
# 74       2008  PHL    JAX
# 79       2008  ABQ    LAS
# 86       2008  ALB    LAS
# 87       2008  AMA    LAS
# 88       2008  AUS    LAS
# 91       2008  BDL    LAS
# 97       2008  BOI    LAS
# 99       2008  BUF    LAS
# 100      2008  BUR    LAS
# 116      2008  CLE    LAS
# 117      2008  CMH    LAS
# 119      2008  DEN    LAS
# 126      2008  ELP    LAS
# 128      2008  GEG    LAS
# ...       ...  ...    ...
# 533778   2008  WRG    KTN
# 533783   2008  PSG    WRG
# 533797   2008  CDV    ANC
# ...

# %%
nw = df.groupby(['Year','Dest', 'Origin']).size()
nw.sort()
nw
# Out:
# Year  Dest  Origin
# 1987  LGB   LAS          1
#       LAS   LAS          1
#       SBA   IAH          1
#       ALB   SYR          1
#       JFK   JFK          1
#       PHX   PHX          1
#       LGA   LGA          1
#       MOB   BHM          1
#       LAS   CID          1
#       PIE   MCO          1
#       SGF   PSP          1
#       ALB   BOS          1
#       PHX   CID          1
#             MLI          1
#       CHA   ORF          1
#       FLL   FLL          1
#       ORD   MDW          1
#       EWR   PIR          1
#       SYR   DAY          1
#       LAX   BUR          1
#       PIH   DEN          1
#       LNK   MDW          1
#       TPA   PIE          1
#       CPR   LAX          1
#       COS   SUX          1
#       DSM   LAS          1
#       SRQ   TPA          1
#       BOS   ALB          1
#       PIT   CAK          1
#       PHL   MDT          1
#                       ...
#       IAH   DFW       2188
#       BOS   EWR       2202
# ...

# %%
nw97 = df97.groupby(['Year','Dest', 'Origin']).size()
nw97.sort()
nw97
# Out:
# Year  Dest  Origin
# 1997  CMH   SDF           1
#       JAX   MCO           1
#       BDL   PVD           1
#       IAD   DCA           1
#             BWI           1
#       HRL   DFW           1
#       ALB   SWF           1
#       HNL   SAN           1
#       BWI   DCA           1
#       BDL   BOS           1
#       LAX   ONT           1
#       LGA   JFK           1
#       SWF   BOS           1
#       LGB   LAS           1
#       OAK   SFO           1
#       GUM   HNL           1
#       BDL   ALB           1
#       SFO   SMF           1
#       FAT   LAX           1
#       EWR   PHL           1
#       SFO   SJC           1
#       CHS   SAV           1
#       STL   HSV           1
#       CID   MLI           1
#       PHL   LFT           1
#       SNA   LAX           1
#       EWR   JFK           2
#       LWB   PIT           2
#       MIA   RSW           2
#       EWR   MTJ           2
#                       ...
#       ORD   ATL       10204
# ...

# %%
nw08 = df08.groupby(['Year','Dest', 'Origin']).size()
nw08.sort()
nw08
# Out:
# Year  Dest  Origin
# 2008  SGF   XNA           1
#       PLN   DCA           1
#       PMD   BUR           1
#       SMF   OAK           1
#       PSP   BUR           1
#             IYK           1
#       HDN   GJT           1
#       PSP   OXR           1
#             SGU           1
#             TUS           1
#       DEN   GRB           1
#       RDD   MFR           1
#             SMF           1
#       TPA   MCO           1
#       RDM   EUG           1
#       DEN   BTR           1
#       RDM   GEG           1
#             MFR           1
#       GTF   GRB           1
#       RDU   ILM           1
#       GTF   BIL           1
#       BNA   CRW           1
#       GJT   YUM           1
#       PIT   ERI           1
#       GRB   BDL           1
#             CMH           1
#             EWR           1
#             FSD           1
#             OMA           1
#       SYR   CMH           1
#                       ...
#       ORD   MSP        9356
# ...

# %%
frames = [nw, nw97, nw08]
result = pd.concat(frames)
result
# Out:
# Year  Dest  Origin
# 1987  LGB   LAS           1
#       LAS   LAS           1
#       SBA   IAH           1
#       ALB   SYR           1
#       JFK   JFK           1
#       PHX   PHX           1
#       LGA   LGA           1
#       MOB   BHM           1
#       LAS   CID           1
#       PIE   MCO           1
#       SGF   PSP           1
#       ALB   BOS           1
#       PHX   CID           1
#             MLI           1
#       CHA   ORF           1
#       FLL   FLL           1
#       ORD   MDW           1
#       EWR   PIR           1
#       SYR   DAY           1
#       LAX   BUR           1
#       PIH   DEN           1
#       LNK   MDW           1
#       TPA   PIE           1
#       CPR   LAX           1
#       COS   SUX           1
#       DSM   LAS           1
#       SRQ   TPA           1
#       BOS   ALB           1
#       PIT   CAK           1
#       PHL   MDT           1
#                       ...
# 2008  ORD   MSP        9356
# ...

# %%
ll_df = pd.read_csv('codes.csv', delimiter=',',engine='python')
ll_df
#df['color'] = np.where(df['Set']=='Z', 'green', 'red')
# Out:
#       locationID  Latitude  Longitude
# 0            ADK   51.8781   176.6461
# 1            AKK   56.9386   154.1825
# 2            Z13   60.9047   161.4225
# 3            AKI   60.9028   161.2306
# 4            AUK   62.6800   164.6600
# 5            5A8   59.2825   158.6178
# 6           4AK7   59.2808   158.5972
# 7            Z25   59.2631   158.5578
# 8            6A8   66.5519   152.6222
# 9            AFM   67.1064   157.8575
# 10          AK80   65.1017   151.1775
# 11           AKP   68.1336   151.7433
# 12          AK00   59.7967   151.8633
# 13          00AK   59.8561   151.6964
# 14           A13   61.3414   148.9989
# 15           CSR   61.1586   149.7806
# 16           EDF   61.2514   149.8064
# 17          6AK5   61.1683   150.1606
# 18          AK12   61.1067   149.8642
# 19           Z41   61.1869   149.9653
# 20           MRI   61.2136   149.8444
# 21          AA05   61.5078   149.0783
# 22          AA06   61.2897   149.8061
# 23          9AK5   61.1164   149.8189
# ...

# %%
ll_df[ll_df['locationID' ] == 'SAN']
listloc = [{},{},]
listloc = ll_df.values
listloc[2][0]
df['Dest'][677]
# Out:
# 'SNA'

# %%
#take only unique airports
somecol = df[['Dest','Origin']]
uniquedf = somecol.drop_duplicates('Dest', inplace = False)
uniquedf = uniquedf.reset_index()
uniquedf.drop('index', axis=1, inplace=True)
uniquedf
# Out:
#     Dest Origin
# 0    SFO    SAN
# 1    RNO    SFO
# 2    OAK    BUR
# 3    BUR    OAK
# 4    LAX    PHX
# 5    PDX    SFO
# 6    SAN    SFO
# 7    LAS    SAN
# 8    SNA    OAK
# 9    SJC    LAX
# 10   ABQ    LAX
# 11   GEG    SFO
# 12   SCK    SFO
# 13   PHX    LAX
# 14   SMF    BUR
# 15   RDM    MFR
# 16   SEA    SFO
# 17   FAT    LAX
# 18   TUS    LAX
# 19   LGB    SFO
# 20   ONT    SFO
# 21   CCR    LAX
# 22   BLI    SEA
# 23   EUG    SFO
# 24   MRY    LAX
# 25   YKM    PSC
# 26   PSC    SFO
# 27   MFR    SFO
# 28   STL    JFK
# 29   HNL    STL
# ..   ...    ...
# 207  LFT    IAH
# 208  ROR    GUM
# 209  YAP    GUM
# 210  SPN    GUM
# 211  GUM    ROR
# 212  MFE    IAH
# 213  MLU    SHV
# 214  CSG    ATL
# 215  HLN    FCA
# 216  FCA    HLN
# 217  JAC    IDA
# 218  IDA    SLC
# 219  JNU    SEA
# 220  BTM    BZN
# 221  PIE    RDU
# 222  TVL    SJC
# 223  PHF    PIT
# 224  BET    ANC
# 225  OME    ANC
# 226  OTZ    OME
# 227  SCC    ANC
# 228  KTN    JNU
# 229  YAK    JNU
# ...

# %%
inst = [{'Dest':'BLR','Origin':'BLR','Olat':0.000000,'Olong':0.000000,'Dlat':0.000000,'Dlong':0.000000}]
nwdf= pd.DataFrame(inst)
nwdf
uniquedf['Dest'][1]
# Out:
# 'RNO'

# %%
for i in range(0,len(listloc)):
    for j in range(0,len(uniquedf)):
        #print listloc[i]
        if uniquedf['Dest'][j] == listloc[i][0]:
            nwdf['Dest'][j]= uniquedf['Dest'][j]
            nwdf['Origin'][j] = uniquedf['Origin'][j]
            nwdf['Dlat'][j] = listloc[i][1]
            nwdf['Dlong'] [j] = listloc[i][2]
nwdf
# Out:
# /Users/aramamurthy/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/aramamurthy/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/IPython/kernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/aramamurthy/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
